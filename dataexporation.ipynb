# %%
import pandas as pd
file_path = 'NTDOY_stock_data.csv'
ntdoy_df = pd.read_csv(file_path)
file_path = 'EA_stock_data.csv'
ea_df = pd.read_csv(file_path)
file_path = 'RIOT_stock_data.csv'
riot_df = pd.read_csv(file_path)
file_path = 'TTWO_stock_data.csv'
ttwo_df = pd.read_csv(file_path)
file_path = 'TCEHY_stock_data.csv'
tchey_df = pd.read_csv(file_path)


# Display the first few rows of the DataFrame
print(ntdoy_df.head())
print(ea_df.head())
print(riot_df.head())
print(ttwo_df.head())
print(tchey_df.head())
# Out:
#          Date   Open   High    Low  Close  Adj Close   Volume
# 0  2019-03-01  6.926  6.950  6.866  6.934      6.934  2462500
# 1  2019-03-04  6.810  6.828  6.704  6.742      6.742  3426500
# 2  2019-03-05  6.796  6.826  6.750  6.810      6.810  1389000
# 3  2019-03-06  6.910  6.958  6.910  6.930      6.930   744500
# 4  2019-03-07  6.834  6.834  6.744  6.762      6.762  1333000
#          Date       Open       High        Low      Close  Adj Close   Volume
# 0  2019-03-01  96.830002  97.940002  95.309998  97.410004  95.533257  4443600
# 1  2019-03-04  98.309998  99.430000  95.570000  97.290001  95.415573  7187200
# 2  2019-03-05  96.260002  97.059998  95.150002  95.720001  93.875824  6041900
# 3  2019-03-06  95.320000  96.379997  94.129997  94.769997  92.944099  3987500
# 4  2019-03-07  95.000000  99.559998  94.470001  99.360001  97.445686  8866800
#          Date  Open   High   Low  Close  Adj Close   Volume
# 0  2019-03-01  3.20  3.480  3.17   3.26       3.26  1034500
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt


# Convert the date column to datetime type
ea_df['Date'] = pd.to_datetime(ea_df['Date'])

# Set the date column as the index of the dataframe
ea_df.set_index('Date', inplace=True)

# Plot the closing stock prices
plt.figure(figsize=(10, 6))  # You can adjust the figure size to your preference
plt.plot(ea_df['Close'], label='Closing Price')

# Customize the plot
plt.title('EA Stock Closing Price Over Time')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt


# Convert the date column to datetime type
ntdoy_df['Date'] = pd.to_datetime(ntdoy_df['Date'])

# Set the date column as the index of the dataframe
ntdoy_df.set_index('Date', inplace=True)

# Plot the closing stock prices
plt.figure(figsize=(10, 6))  # You can adjust the figure size to your preference
plt.plot(ntdoy_df['Close'], label='Closing Price')

# Customize the plot
plt.title('NTDOY Stock Closing Price Over Time')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt


# Convert the date column to datetime type
ttwo_df['Date'] = pd.to_datetime(ttwo_df['Date'])

# Set the date column as the index of the dataframe
ttwo_df.set_index('Date', inplace=True)

# Plot the closing stock prices
plt.figure(figsize=(10, 6))  # You can adjust the figure size to your preference
plt.plot(ttwo_df['Close'], label='Closing Price')

# Customize the plot
plt.title('TTWO Stock Closing Price Over Time')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt


# Convert the date column to datetime type
riot_df['Date'] = pd.to_datetime(riot_df['Date'])

# Set the date column as the index of the dataframe
riot_df.set_index('Date', inplace=True)

# Plot the closing stock prices
plt.figure(figsize=(10, 6))  # You can adjust the figure size to your preference
plt.plot(riot_df['Close'], label='Closing Price')

# Customize the plot
plt.title('RIOT Stock Closing Price Over Time')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt


# Convert the date column to datetime type
tchey_df['Date'] = pd.to_datetime(tchey_df['Date'])

# Set the date column as the index of the dataframe
tchey_df.set_index('Date', inplace=True)

# Plot the closing stock prices
plt.figure(figsize=(10, 6))  # You can adjust the figure size to your preference
plt.plot(tchey_df['Close'], label='Closing Price')

# Customize the plot
plt.title('TCHEY Stock Closing Price Over Time')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()
